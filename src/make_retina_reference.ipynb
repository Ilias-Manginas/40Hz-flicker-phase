# %%
# Imports
import gc
import helpers.helper_functions as hf
import mne
import matplotlib.pyplot as plt
import os.path as op
from mne.channels import combine_channels
import pandas as pd
from mne.beamformer import make_lcmv, apply_lcmv_epochs
from pathlib import Path



ss = hf.settings_dict()

# %%
for subject_index in ss['subject_idx_list']:

    subject = ss['subject_id_list'][subject_index]
    print("loading raw dataset for subject: ", subject)

    epochs = mne.read_epochs(op.join(ss['epochs_dir'],subject+"-epo.fif"), preload=True)

    # loop over each event type
    for event_name in epochs.event_id.keys():
        event_epochs = epochs[event_name]

        save_dir = Path(ss['stc_dir']) / subject / event_name
        save_dir.mkdir(parents=True, exist_ok=True)

        for i in range(ss['n_trials']):
            trial_epoch = event_epochs[i]

            # extract the retina signal and save it to a file
            times = trial_epoch.times

            if len(ss['retina_channels']) > 0:
                # Convert names to indices
                retina_indices = [trial_epoch.ch_names.index(ch) for ch in ss['retina_channels']]

                # Create a new Evoked with the averaged channel
                retina = combine_channels(
                    trial_epoch,
                    groups=dict(avg=retina_indices),
                    method='mean'
                )

                retina_data = retina._data[0]
            else:

                idx = trial_epoch.ch_names.index(ss['retina_channels'][0])
                # Extract data

                retina_data = trial_epoch._data[idx]

            # Create dataframe
            df = pd.DataFrame({
                "time_s": times,
                "amplitude": retina_data[0],
            })

            # Save to CSV
            df.to_csv(save_dir / f"{subject}-trial-{i}-retina.csv" , index=False)
# Out:
# loading raw dataset for subject:  0005_3SJ
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0005_3SJ-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# loading raw dataset for subject:  0002_TCZ
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0002_TCZ-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# loading raw dataset for subject:  0009_YGZ
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0009_YGZ-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# loading raw dataset for subject:  0010_ZMG
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0010_ZMG-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# loading raw dataset for subject:  0011_MEE
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0011_MEE-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# loading raw dataset for subject:  0012_C3Z
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0012_C3Z-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# ...
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# loading raw dataset for subject:  0019_COG
# Reading /media/elias/data/thesis_intermediate/data/scratch/epochs/0019_COG-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# 1 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
