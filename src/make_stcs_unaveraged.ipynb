# %%
# Imports
import gc
import helpers.helper_functions as hf
import mne
import matplotlib.pyplot as plt
import os.path as op
from mne.channels import combine_channels
import pandas as pd
from mne.beamformer import make_lcmv, apply_lcmv_epochs
from pathlib import Path



ss = hf.settings_dict()

# %%
# Parameters

#data covariance times
tmax = 3.7 - 1/ss['fs']
tmin = 0.7
base_tmin = -0.5 + (1/ss['fs'])
base_tmax = 0.0
method = 'empirical'

#beamformer parameters
reg=0.05
pick_ori='max-power'
weight_norm='nai'

# %%
for subject_index in ss['subject_idx_list']:

    subjects_dir = ss['fs_subjects_dir']
    subject = ss['subject_id_list'][subject_index]
    print("loading dataset for subject: ", subject)

    epochs = mne.read_epochs(op.join(ss['epochs_dir'],subject+"-epo.fif"), preload=True)

    # now manking the stc
    epochs.pick('grad')

    #Load forward model
    #TODO: check that the forward models are correct
    fwd = hf.load_fwd_model(subject)

    #Source localization

    #make data covariance matrix
    stim_cov = mne.compute_covariance(epochs, tmin=tmin, tmax=tmax, method=method)
    base_cov = mne.compute_covariance(epochs, tmin=base_tmin, tmax=base_tmax, method=method)

    data_cov = stim_cov

    cov_plot = data_cov.plot(info = epochs.info, show= False)
    cov_plot[0].suptitle(f"subject {subject} ", fontsize=16)
    plt.show()

    for event_id in ss['event_id_list']:
        event_name = str(event_id)

        save_dir = Path(ss['stc_unaveraged_dir']) / subject / event_name
        save_dir.mkdir(parents=True, exist_ok=True)

        event_epochs = epochs[event_name]

        sp_filter = make_lcmv(
            event_epochs.info,
            fwd,
            data_cov=data_cov,
            noise_cov=base_cov,
            reg=reg,
            pick_ori=pick_ori,
            weight_norm=weight_norm,
            rank=None,
        )

        stcs = apply_lcmv_epochs(event_epochs, sp_filter)

        for i in range(ss['n_trials']):
            stcs[i].save(save_dir / f"{subject}-{i}-vol.stc" , overwrite=True)

    del stcs
    del epochs

gc.collect()
# Out:
# loading dataset for subject:  0005_3SJ
# Reading /home/elias/Documents/thesis_intermediate/data/scratch/epochs/0005_3SJ-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0005_3SJ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1440 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 420000
# [done]
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 42000
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.31  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.8e-15 (2.2e-16 eps * 203 dim * 0.063  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1440 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# loading dataset for subject:  0002_TCZ
# Reading /home/elias/Documents/thesis_intermediate/data/scratch/epochs/0002_TCZ-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0002_TCZ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1868 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 420000
# [done]
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 42000
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.2e-14 (2.2e-16 eps * 203 dim * 0.26  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.6e-15 (2.2e-16 eps * 203 dim * 0.057  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1868 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# loading dataset for subject:  0009_YGZ
# Reading /home/elias/Documents/thesis_intermediate/data/scratch/epochs/0009_YGZ-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0009_YGZ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1225 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 420000
# [done]
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 42000
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 1.4e-14 (2.2e-16 eps * 203 dim * 0.3  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2e-15 (2.2e-16 eps * 203 dim * 0.043  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1225 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# loading dataset for subject:  0010_ZMG
# Reading /home/elias/Documents/thesis_intermediate/data/scratch/epochs/0010_ZMG-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0010_ZMG-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1212 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 420000
# [done]
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 42000
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 5.7e-15 (2.2e-16 eps * 203 dim * 0.13  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 5.7e-15 (2.2e-16 eps * 203 dim * 0.13  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 1.9e-15 (2.2e-16 eps * 203 dim * 0.041  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1212 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# ...
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# loading dataset for subject:  0019_COG
# Reading /home/elias/Documents/thesis_intermediate/data/scratch/epochs/0019_COG-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    4499.50 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0019_COG-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1446 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 420000
# [done]
# Reducing data rank from 203 -> 203
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 42000
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Computing rank from covariance with rank=None
#     Using tolerance 2.3e-14 (2.2e-16 eps * 203 dim * 0.52  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Computing rank from covariance with rank=None
#     Using tolerance 7.3e-15 (2.2e-16 eps * 203 dim * 0.16  max singular value)
#     Estimated rank (grad): 203
#     GRAD: rank 203 computed from 203 data channels with 0 projectors
# Making LCMV beamformer with rank {'grad': 203}
# Computing inverse operator with 203 channels.
#     203 out of 306 channels remain after picking
# Selected 203 channels
# Whitening the forward solution.
# Computing rank from covariance with rank={'grad': 203}
#     Setting small GRAD eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing beamformer filters for 1446 sources
# Filter computation complete
# Processing epoch : 1
# Processing epoch : 2
# Processing epoch : 3
# Processing epoch : 4
# Processing epoch : 5
# Processing epoch : 6
# Processing epoch : 7
# Processing epoch : 8
# Processing epoch : 9
# Processing epoch : 10
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# Overwriting existing file.
# Writing STC to disk...
# Overwriting existing file.
# [done]
# 50482
