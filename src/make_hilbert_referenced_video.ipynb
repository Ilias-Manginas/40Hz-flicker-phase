# %%
# Imports

import helpers.helper_functions as hf
import mne
import os.path as op
from mne.channels import combine_channels
import pandas as pd
from mne.beamformer import make_lcmv, apply_lcmv_epochs
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import hilbert
import helpers.test_circ_plot as circ_plot
import gc
import helpers.stc_helper as stc_helper
import time

ss = hf.settings_dict()

# %%
#important variables
tmin = 1.7
tmax = 2.7
event_id =4
n_workers = 10

# %%
# %matplotlib Agg
for subject_index in ss['subject_idx_list']:
    event_name = str(event_id)
    duty_cycle = ss['event_name_list'][event_id-1]
    subjects_dir = ss['fs_subjects_dir']
    subject = ss['subject_id_list'][subject_index]
    print("loading dataset for subject: ", subject)

    # load hilbert stc data
    phase_diff_voxel_stc_file = Path(ss['hilbert_ref_dir']) / subject / event_name / f"{subject}-event-{event_name}-hilbert-vox-ref-vol.stc"
    phase_diff_voxel_stc = mne.read_source_estimate(phase_diff_voxel_stc_file)
    phase_diff_retina_stc_file = Path(ss['hilbert_ref_dir']) / subject / event_name / f"{subject}-event-{event_name}-hilbert-ret-ref-vol.stc"
    phase_diff_retina_stc = mne.read_source_estimate(phase_diff_retina_stc_file)


    # load forward model
    fwd_fname = op.join(ss['fwd_dir'], subject + '-fwd.fif')
    fwd = mne.read_forward_solution(fwd_fname)
    src = fwd['src']

    # get reference voxel coordinates
    # load hilbert references
    reference_file = Path(ss['hilbert_dir']) / subject / event_name / f"{subject}-event-{event_name}-reference.csv"

    # Read the CSV file
    df = pd.read_csv(reference_file)
    # get voxel number
    voxel = int(df.axes[1][2].split("_")[0])

    coords = stc_helper.extract_voxel_coords_from_stc(stc=phase_diff_retina_stc, voxel=voxel, src=src)


    save_dir = Path(ss['hilbert_ref_dir']) / "video" / subject / event_name
    save_dir.mkdir(parents=True, exist_ok=True)

    circ_plot.plot_dual_circ_stat_map_video(phase_diff_voxel_stc.copy().crop(tmin=tmin, tmax=tmax),
                                            phase_diff_retina_stc.copy().crop(tmin=tmin, tmax=tmax),
                                             subject=subject,
                                             subjects_dir=subjects_dir,
                                             cut_coords=coords,
                                             draw_cross=True,
                                             title1=f"{subject}  |  {duty_cycle} %  |  voxel as reference",
                                             title2=f"{subject}  |  {duty_cycle} %  |  retina as reference",
                                             fps=2,
                                             dpi=220,
                                             time_indices = None,
                                             output_path=save_dir / f"{subject}-event-{event_name}-hilbert-ref-vol.mp4",
                                             n_workers=n_workers,)


    del phase_diff_voxel_stc
    del phase_diff_retina_stc
    gc.collect()
    time.sleep(10)
# Out:
# loading dataset for subject:  0005_3SJ
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0005_3SJ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1440 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0005_3SJ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1440 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Pre-computing 2001 volumes...
# 100%|██████████| 2001/2001 [05:44<00:00,  5.82it/s]
# Rendering frames with 10 processes...
# 100%|██████████| 2001/2001 [16:29<00:00,  2.02it/s]
# Assembling video...
# Video saved to: /home/elias/Documents/thesis_intermediate/data/scratch/hilbert_reference/video/0005_3SJ/4/0005_3SJ-event-4-hilbert-ref-vol.mp4
# loading dataset for subject:  0002_TCZ
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0002_TCZ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1868 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0002_TCZ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1868 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Pre-computing 2001 volumes...
# 100%|██████████| 2001/2001 [06:32<00:00,  5.10it/s]
# Rendering frames with 10 processes...
#  15%|█▍        | 298/2001 [02:44<10:46,  2.63it/s]
