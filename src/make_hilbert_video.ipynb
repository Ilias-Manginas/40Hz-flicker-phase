# %%
# Imports

import helpers.helper_functions as hf
import mne
import os.path as op
from mne.channels import combine_channels
import pandas as pd
from mne.beamformer import make_lcmv, apply_lcmv_epochs
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import hilbert
import helpers.test_circ_plot as circ_plot
import time
import gc

ss = hf.settings_dict()

# %%
#important variables
tmin = 1.7
tmax = 2.7
event_id =4
n_workers = 11

# %%
# %matplotlib Agg
for subject_index in ss['subject_idx_list']:
    # loop over each event type
    event_name = str(event_id)
    duty_cycle = ss['event_name_list'][event_id-1]
    subjects_dir = ss['fs_subjects_dir']
    subject = ss['subject_id_list'][subject_index]
    print("loading dataset for subject: ", subject)
    hilbert_stc_file = Path(ss['hilbert_dir']) / subject / event_name / f"{subject}-event-{event_name}-hilbert-vol.stc"

    stc = mne.read_source_estimate(hilbert_stc_file)

    save_dir = Path(ss['hilbert_dir']) / "video" / subject / event_name
    save_dir.mkdir(parents=True, exist_ok=True)

    # indices = np.where((stc.times >= tmin) & (stc.times <= tmax))[0]

    circ_plot.plot_circ_stat_map_video(stc=stc.copy().crop(tmin=tmin, tmax=tmax),
                                       subjects_dir=subjects_dir,
                                       subject=subject,
                                       # event_name=event_name,
                                       fps=2,
                                       dpi=220,
                                       time_indices = None,
                                       output_path=save_dir / f"{subject}-event-{event_name}-hilbert-vol.mp4",
                                       title = f"{subject}  |  {duty_cycle} %",
                                       n_workers=n_workers
                                       )

    del stc
    gc.collect()

    time.sleep(10)
# Out:
# loading dataset for subject:  0005_3SJ
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0005_3SJ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1440 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Pre-computing 2001 volumes...
# 100%|██████████| 2001/2001 [04:03<00:00,  8.21it/s]
# Rendering frames with 11 processes...
# 100%|██████████| 2001/2001 [06:43<00:00,  4.96it/s]
# Assembling video...
# Video saved to: /home/elias/Documents/thesis_intermediate/data/scratch/hilbert/video/0005_3SJ/4/0005_3SJ-event-4-hilbert-vol.mp4
# loading dataset for subject:  0002_TCZ
# Reading forward solution from /media/elias/Personal Data/Documents/masters/Thesis/data/scratch/fwd/0002_TCZ-fwd.fif...
#     Reading a source space...
#     [done]
#     1 source spaces read
#     Desired named matrix (kind = 3523 (FIFF_MNE_FORWARD_SOLUTION_GRAD)) not available
#     Read MEG forward solution (1868 sources, 306 channels, free orientations)
#     Source spaces transformed to the forward solution coordinate frame
# Pre-computing 2001 volumes...
#   1%|          | 17/2001 [00:02<04:29,  7.35it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      14 save_dir.mkdir(parents=True, exist_ok=True)
#      16 # indices = np.where((stc.times >= tmin) & (stc.times <= tmax))[0]
# ---> 18 circ_plot.plot_circ_stat_map_video(stc=stc.copy().crop(tmin=tmin, tmax=tmax),
#      19                                    subjects_dir=subjects_dir,
#      20                                    subject=subject,
#      21                                    # event_name=event_name,
#      22                                    fps=2,
#      23                                    dpi=220,
#      24                                    time_indices = None,
#      25                                    output_path=save_dir / f"{subject}-event-{event_name}-hilbert-vol.mp4",
#      26                                    title = f"{subject}  |  {duty_cycle}",
#      27                                    n_workers=n_workers
#      28                                    )
#      30 del stc
#      31 gc.collect()
#
# File ~/Workspace/thesis/iliasgdk_thesis/src/helpers/test_circ_plot.py:144, in plot_circ_stat_map_video(stc, subject, subjects_dir, output_path, title, cut_coords, draw_cross, fps, time_indices, dpi, n_workers)
#     142 stc_t.tmin = t
#     143 stc_t.tstep = stc.tstep
# --> 144 img = index_img(stc_t.as_volume(src), 0)
#     146 del stc_t   # explicitly free after volume conversion
#     147 gc.collect()
#
# File ~/miniconda3/envs/iliasgdk_thesis/lib/python3.13/site-packages/mne/source_estimate.py:2616, in _BaseVolSourceEstimate.as_volume(self, src, dest, mri_resolution, format)
#    2613 from .morph import _interpolate_data
#    2615 data = self.magnitude() if self._data_ndim == 3 else self
# -> 2616 return _interpolate_data(
#    2617     data, src, mri_resolution=mri_resolution, mri_space=True, output=format
#    2618 )
#
# File ~/miniconda3/envs/iliasgdk_thesis/lib/python3.13/site-packages/mne/morph.py:1073, in _interpolate_data(stc, morph, mri_resolution, mri_space, output)
#    1071     assert len(set(map(tuple, src_shape))) == 1
#    1072     src_subject = morph._subject
# -> 1073     morph = BunchConst(src_data=_get_src_data(morph, mri_resolution)[0])
#    1074 else:
#    1075     # Make a list as we may have many inuse when using multiple sub-volumes
#    1076     inuse = morph.src_data["inuse"]
#
# File ~/miniconda3/envs/iliasgdk_thesis/lib/python3.13/site-packages/mne/morph.py:999, in _get_src_data(***failed resolving arguments***)
#     997         break
#     998 else:
# --> 999     interpolator = sum((s["interpolator"] for s in src_t[start:]), 0.0)
#    1000 inuses = [s["inuse"] for s in src_t[start:]]
#    1001 src_data.update(
#    1002     {
#    1003         "src_shape": (shape[2], shape[1], shape[0]),  # SAR
#    (...)   1015     }
#    1016 )
#
# File ~/miniconda3/envs/iliasgdk_thesis/lib/python3.13/site-packages/scipy/sparse/_base.py:758, in _spbase.__radd__(self, other)
#     757 def __radd__(self,other):  # other + self
# --> 758     return self.__add__(other)
#
# File ~/miniconda3/envs/iliasgdk_thesis/lib/python3.13/site-packages/scipy/sparse/_base.py:743, in _spbase.__add__(self, other)
#     741 if isscalarlike(other):
#     742     if other == 0:
# --> 743         return self.copy()
#     744     # Now we would add this scalar to every element.
#     745     raise NotImplementedError('adding a nonzero scalar to a '
#     746                               'sparse array is not supported')
#
# File ~/miniconda3/envs/iliasgdk_thesis/lib/python3.13/site-packages/scipy/sparse/_data.py:95, in _data_matrix.copy(self)
#      94 def copy(self):
# ---> 95     return self._with_data(self.data.copy(), copy=True)
#
# KeyboardInterrupt:
