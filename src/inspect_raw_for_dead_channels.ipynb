# %%
from fcntl import FASYNC

# imports

import helpers.helper_functions as hf

import numpy as np
import mne

# %% [markdown]
# Load all datasets one by one and open an interactive window to inspect for bad channels

# %%
# %gui qt
mne.viz.set_browser_backend("qt")

ss = hf.settings_dict()

first_iter = True

for subject_index in ss['subject_idx_list']:

    subject = ss['subject_id_list'][subject_index]
    print("loading raw dataset for subject: ", subject)

    raw = hf.load_raw(subject=subject_index, preload=True)

    if first_iter:
        raw.plot_sensors(kind='topomap', show_names=True)

    # drop projectors
    ssp_projectors = raw.info["projs"]
    raw.del_proj()

    raw.plot(theme = 'light', block = True, title = subject)

    del raw
# Out:
# Using qt as 2D backend.
# loading raw dataset for subject:  0005_3SJ
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0005/20180514_000000/MEG/001.flicker/files/flicker.fif...
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 73000 ... 1218999 =     36.500 ...   609.500 secs
# Ready.
# Reading 0 ... 1145999  =      0.000 ...   573.000 secs...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0005/20180514_000000/MEG/001.flicker/files/flicker.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0002_TCZ
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0002/20180522_000000/MEG/001.s2/files/s2.fif...
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 93000 ... 1274999 =     46.500 ...   637.500 secs
# Ready.
# Reading 0 ... 1181999  =      0.000 ...   591.000 secs...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0002/20180522_000000/MEG/001.s2/files/s2.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
# Waiting for Loading-Thread to finish... (max. 10 sec)
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0009_YGZ
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0009/20180522_000000/MEG/001.s3p1/files/s3p1.fif...
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 53000 ... 711999 =     26.500 ...   356.000 secs
# Ready.
# Reading 0 ... 658999  =      0.000 ...   329.500 secs...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:38: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0009/20180522_000000/MEG/001.s3p1/files/s3p1.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw1 = mne.io.read_raw_fif(raw_fname1, preload=preload)
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0009/20180522_000000/MEG/002.s3p2/files/s3p2.fif...
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 38000 ... 540999 =     19.000 ...   270.500 secs
# Ready.
# Reading 0 ... 502999  =      0.000 ...   251.500 secs...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:39: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0009/20180522_000000/MEG/002.s3p2/files/s3p2.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw2 = mne.io.read_raw_fif(raw_fname2, preload=preload)
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:40: RuntimeWarning: raws[1].info['dev_head_t'] differs. The instances probably come from different runs, and are therefore associated with different head positions. Manually change info['dev_head_t'] to avoid this message but beware that this means the MEG sensors will not be properly spatially aligned. See mne.preprocessing.maxwell_filter to realign the runs to a common head position.
#   raw = mne.concatenate_raws([raw1,raw2], on_mismatch='warn')
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0010_ZMG
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0010/20180523_000000/MEG/001.s4/files/s4.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0010/20180523_000000/MEG/001.s4/files/s4.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 87000 ... 1286999 =     43.500 ...   643.500 secs
# Ready.
# Reading 0 ... 1199999  =      0.000 ...   600.000 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0011_MEE
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0011/20180524_000000/MEG/001.s5/files/s5.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0011/20180524_000000/MEG/001.s5/files/s5.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 21000 ... 1219999 =     10.500 ...   610.000 secs
# Ready.
# Reading 0 ... 1198999  =      0.000 ...   599.500 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0012_C3Z
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0012/20180524_000000/MEG/001.s6/files/s6.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0012/20180524_000000/MEG/001.s6/files/s6.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 59000 ... 1321999 =     29.500 ...   661.000 secs
# Ready.
# Reading 0 ... 1262999  =      0.000 ...   631.500 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0014_TAG
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0014/20180525_000000/MEG/001.s7/files/s7.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0014/20180525_000000/MEG/001.s7/files/s7.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 526000 ... 1703999 =    263.000 ...   852.000 secs
# Ready.
# Reading 0 ... 1177999  =      0.000 ...   589.000 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0015_QKW
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0015/20180525_000000/MEG/001.s8/files/s8.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0015/20180525_000000/MEG/001.s8/files/s8.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 153000 ... 1337999 =     76.500 ...   669.000 secs
# Ready.
# Reading 0 ... 1184999  =      0.000 ...   592.500 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0016_XLZ
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0016/20180525_000000/MEG/001.s9p1/files/s9p1.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:38: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0016/20180525_000000/MEG/001.s9p1/files/s9p1.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw1 = mne.io.read_raw_fif(raw_fname1, preload=preload)
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 68000 ... 724999 =     34.000 ...   362.500 secs
# Ready.
# Reading 0 ... 656999  =      0.000 ...   328.500 secs...
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0016/20180525_000000/MEG/002.s9p2/files/s9p2.fif...
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:39: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0016/20180525_000000/MEG/002.s9p2/files/s9p2.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw2 = mne.io.read_raw_fif(raw_fname2, preload=preload)
#     Range : 26000 ... 615999 =     13.000 ...   308.000 secs
# Ready.
# Reading 0 ... 589999  =      0.000 ...   295.000 secs...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:40: RuntimeWarning: raws[1].info['dev_head_t'] differs. The instances probably come from different runs, and are therefore associated with different head positions. Manually change info['dev_head_t'] to avoid this message but beware that this means the MEG sensors will not be properly spatially aligned. See mne.preprocessing.maxwell_filter to realign the runs to a common head position.
#   raw = mne.concatenate_raws([raw1,raw2], on_mismatch='warn')
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0017_QJ5
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0017/20180530_000000/MEG/001.s10/files/s10.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0017/20180530_000000/MEG/001.s10/files/s10.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 249000 ... 1439999 =    124.500 ...   720.000 secs
# Ready.
# Reading 0 ... 1190999  =      0.000 ...   595.500 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0018_5T3
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0018/20180530_000000/MEG/001.s11/files/s11.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0018/20180530_000000/MEG/001.s11/files/s11.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 81000 ... 1259999 =     40.500 ...   630.000 secs
# Ready.
# Reading 0 ... 1178999  =      0.000 ...   589.500 secs...
# Channels marked as bad:
# ['MEG1143']
# loading raw dataset for subject:  0019_COG
# Opening raw data file /media/elias/Personal Data/Documents/masters/Thesis/data/raw/0019/20180530_000000/MEG/001.s12/files/s12.fif...
# /home/elias/Documents/workspace/masters/Thesis/iliasgdk_thesis/src/helpers/helper_functions.py:42: RuntimeWarning: This filename (/media/elias/Personal Data/Documents/masters/Thesis/data/raw/0019/20180530_000000/MEG/001.s12/files/s12.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(raw_fname1, preload=preload)  # raw meg data
#     Read a total of 13 projection items:
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#         generated with autossp-1.2.0 (1 x 306)  idle
#     Range : 40000 ... 1215999 =     20.000 ...   608.000 secs
# Ready.
# Reading 0 ... 1175999  =      0.000 ...   588.000 secs...
# Channels marked as bad:
# ['MEG1143']
